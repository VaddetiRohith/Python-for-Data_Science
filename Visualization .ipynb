# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# Marplotlib Line plot

# %%
x = np.linspace(1,10,15)
y = [1,2,65,4,21,25,36,12,45,89,6,95,56,45,85]
plt.plot(x,y)

# %%
plt.rcParams['figure.figsize'] = (10, 5)

# %%
plt.plot(x,y, 'r--')

# %%
plt.rcParams['figure.dpi'] = 50

# %%
# Out:
# 0
